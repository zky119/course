# %%
import numpy as np
import pandas as pd

# %%
relation = pd.read_csv('officer_relationship_song.csv')
kinship = pd.read_csv('./officer_kinship_song.csv')

# %%
relation.head()
# Out:
#               Name   姓名  Index year Sex       Associate 社会关系人姓名  \
# 0           An Dun   安惇        1042   M         Zou Hao      邹浩
# 1           An Dun   安惇        1042   M  Zhang Shiliang     张士良
# 2     Chen Jian(2)   陈戬        1081   M       Tong Guan      童贯
# 3         Cheng Yu   程瑀        1087   M          Wu Min      吴敏
# 4  Zhang Shangying  张商英        1043   M      Sima Guang     司马光
#
#    Assoc. Index Year Assoc. Sex          Association     联系  ... 亲属关系  \
# 0             1060.0          M  Opposed or attacked  反对/攻讦  ...   未详
# 1                NaN          M  Opposed or attacked  反对/攻讦  ...   未详
# 2             1054.0          M  Opposed or attacked  反对/攻讦  ...   未详
# 3             1087.0          M  Opposed or attacked  反对/攻讦  ...   未详
# 4             1019.0          M  Opposed or attacked  反对/攻讦  ...   未详
#
#     Kin Name  亲戚姓名  Assoc. Kinship Rel. 关系人的亲属关系 Assoc. Kin Name  关系人的亲戚姓名  \
# 0  Wei Xiang    未详                    U       未详       Wei Xiang        未详
# ...

# %%
relation.shape
# Out:
# (506, 29)

# %%
relation['姓名'].value_counts()
# Out:
# 秦桧     63
# 章惇     30
# 司马光    22
# 王安石    21
# 李纲     17
#        ..
# 曾肇      1
# 范如圭     1
# 胡瑗      1
# 王珪      1
# 韩熙载     1
# Name: 姓名, Length: 188, dtype: int64

# %%
relation[relation['Sex']== 'F']
# Out:
#                                 Name        姓名  Index year Sex   Associate  \
# 65         Gao Shi(Wife of Zhao Shu)   高氏(赵曙妻)        1032   F  Wang Anshi
# 73   Liu Shi(Empress of Zhao Heng  )  刘氏(赵恒皇后)         969   F   Cheng Lin
# 333       Meng Shi(Wife of Zhao Xu )   孟氏(赵煦妻)        1077   F    Zeng Dan
# 336      Li Shi(Mother of Zhao Zhen)   李氏(赵祯母)         987   F   Lv Yijian
# 395        Gao Shi(Wife of Zhao Shu)   高氏(赵曙妻)        1032   F  Sima Guang
#
#     社会关系人姓名  Assoc. Index Year Assoc. Sex          Association      联系  ...  \
# 65      王安石             1021.0          M  Opposed or attacked   反对/攻讦  ...
# 73       程琳              988.0          M  Opposed or attacked   反对/攻讦  ...
# 333      曾诞             1067.0          M         Supported by  得到Y的支持  ...
# 336     吕夷简              979.0          M         Supported by  得到Y的支持  ...
# 395     司马光             1019.0          M            Supported      支持  ...
#
# ...
