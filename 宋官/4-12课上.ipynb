# %%
import pandas as pd

# %%
relation = pd.read_csv('./officer_relationship_song.csv')
kinship = pd.read_csv('./officer_kinship_song.csv')

# %%
relation['姓名'].unique()
# Out:
# array(['安惇', '陈戬', '程瑀', '张商英', '章惇', '周嘉正', '范如圭', '韩缜', '许将', '寇准',
#        '高若讷', '郭贽', '郭知章', '李师中', '李迪', '吕颐浩', '潘良贵', '彭汝砺', '彭思永', '施昌言',
#        '司马光', '苏辙', '孙固', '蔡承禧', '曾布', '王纶', '吴懋', '邹浩', '范祖禹', '刘安世',
#        '吕诲', '陈瓘', '师骥', '秦桧', '赵普', '赵鼎', '朱胜非', '胡宿', '李处耘', '李光', '李邴',
#        '吕夷简', '马知节', '王旦', '岳飞', '洪皓', '刘筠', '陈次升', '高氏(赵曙妻)', '杨徽之',
#        '叶祖洽', '邢焕', '黄策', '刘氏(赵恒皇后)', '王公彦', '高登', '李宾王', '唐重', '陈执中',
#        '程琳', '范纯仁', '范纯礼', '韩忠彦', '夏竦', '向子諲', '胡宗愈', '吕惠卿', '吕大防', '皮公弼',
#        '丁谓', '王安石', '王钦若', '王畴', '王珪', '王尧臣', '晏殊', '胡瑗', '苏轼', '曾肇',
#        '黄庭坚', '柳瑊', '柴禹锡', '秦熺', '郑雍', '贾昌朝', '种师道', '何执中', '李纲', '李邦彦',
#        '卢多逊', '汪伯彦', '王黼', '王显', '杨愿', '余靖', '向宗良', '苗傅', '张康国', '周敦颐',
#        '富弼', '韩琦', '胡则', '潘美', '祖无择', '杜衍', '程颐', '章縡', '宋乔年', '宗泽',
#        '常安民', '贾蕃', '苏舜钦', '尹洙', '章綡', '江褒', '郑居中', '范仲淹', '鲁宗道', '狄青',
#        '曹利用', '温益', '赵匡胤', '赵祯', '张载', '张扩', '郑侠', '孟彦卿', '孟氏(赵煦妻)', '刘錡',
#        '李氏(赵祯母)', '马伸', '范琼', '施庭臣', '张士逊', '范同', '冯京', '薛奎', '万俟卨',
#        '沈季长', '苏安世', '王安礼', '王祖道', '吴充', '杨畏', '萧服', '高琼', '曹修古', '张邵',
#        '赵槩', '范宗尹', '韩世忠', '邓洵武', '赵顼', '胡宪', '郑獬', '郑刚中', '石介', '常秩',
#        '邓肃', '句龙如渊', '李渭', '令狐挻', '陈若拙', '陈尧佐', '张知白', '张逊', '赵玭', '赵抃',
#        '李弥大', '沈辽', '孙览', '杨覃', '范镇', '王震', '胥偃', '侯蒙', '吴玠', '汪藻', '张九成',
#        '邵伯温', '范濬', '薛弼', '唐介', '杨偕', '安扶', '孔道辅', '刘安上', '韩熙载'],
#       dtype=object)

# %%
kinship
# Out:
#                              Name       姓名     Kin Name 亲戚姓名 Kinship
# 0                          An Dun       安惇      An Fang   安邡       S
# 1                          An Dun       安惇      An Fang   安邡       S
# 2                          An Dun       安惇      An Fang   安邡       S
# 3                          An Dun       安惇      An Fang   安邡       S
# 4                          An Dun       安惇      An Fang   安邡       S
# ...                           ...      ...          ...  ...     ...
# 1940  Li Shi(Mother of Zhao Zhen)  李氏(赵祯母)     Li Rende  李仁德       F
# 1941  Li Shi(Mother of Zhao Zhen)  李氏(赵祯母)    Zhao Zhen   赵祯       S
# 1942  Li Shi(Mother of Zhao Zhen)  李氏(赵祯母)    Li Yonghe  李用和      B-
# 1943                 Shi Tingchen      施庭臣  Shi Yuanran  施渊然       S
# 1944                    Han Xizai      韩熙载  Han Guangsi  韩光嗣       F
#
# [1945 rows x 5 columns]

# %%
relation['姓名'].nunique()
# Out:
# 188

# %%
relation.columns
# Out:
# Index(['Name', '姓名', 'Index year', 'Sex', 'Associate', '社会关系人姓名',
#        'Assoc. Index Year', 'Assoc. Sex', 'Association', '联系', 'Address', '籍贯',
#        'X', 'Y', 'Assoc. Address', '联系人籍贯', 'Assoc. X', 'Assoc. Y',
#        'Kinship Relation', '亲属关系', 'Kin Name', '亲戚姓名', 'Assoc. Kinship Rel.',
#        '关系人的亲属关系', 'Assoc. Kin Name', '关系人的亲戚姓名', 'Distance 距离', 'Person ID',
#        'Assoc ID'],
#       dtype='object')

# %%
relation['社会关系人姓名'].nunique()
# Out:
# 312

# %% [markdown]
# ### 3.每个官员有多少个关系人

# %%
y = realation.groupby('姓名')['社会关系人姓名'].count().sort_values(ascending = False)
y
# Out:
# 姓名
# 秦桧     63
# 章惇     30
# 司马光    22
# 王安石    21
# 李纲     17
#        ..
# 李迪      1
# 李邴      1
# 杨偕      1
# 柳瑊      1
# 黄策      1
# Name: 社会关系人姓名, Length: 188, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
from pylab import mpl
mpl.rcParams['font.sans-serif']=['SimHei']  # 结局字体问题

plt.title('官员-亲戚数量')
bar = plt.bar(np.arange(len(y)),y)
plt.show()

# %%
officer = set(relation['姓名'])
associate = set(realation['社会关系人姓名'])
kin = set(kinship['亲戚姓名'])

# %%
officer
# Out:
# {'丁谓',
#  '万俟卨',
#  '令狐挻',
#  '何执中',
#  '余靖',
#  '侯蒙',
#  '冯京',
#  '刘安上',
#  '刘安世',
#  '刘氏(赵恒皇后)',
#  '刘筠',
#  '刘錡',
#  '卢多逊',
#  '句龙如渊',
#  '叶祖洽',
#  '司马光',
#  '向子諲',
#  '向宗良',
#  '吕大防',
#  '吕夷简',
#  '吕惠卿',
#  '吕诲',
#  '吕颐浩',
#  '吴充',
#  '吴懋',
#  '吴玠',
#  '周嘉正',
#  '周敦颐',
#  '唐介',
#  '唐重',
#  '夏竦',
#  '孔道辅',
#  '孙固',
#  '孙览',
#  '孟彦卿',
#  '孟氏(赵煦妻)',
#  '安惇',
#  '安扶',
#  '宋乔年',
#  '宗泽',
#  '寇准',
#  '富弼',
#  '尹洙',
#  '岳飞',
#  '师骥',
#  '常安民',
#  '常秩',
#  '张九成',
#  '张商英',
#  '张士逊',
#  '张康国',
#  '张扩',
#  '张知白',
#  '张载',
#  '张逊',
#  '张邵',
#  '彭思永',
#  '彭汝砺',
#  '施庭臣',
#  '施昌言',
#  '晏殊',
#  '曹修古',
#  '曹利用',
#  '曾布',
#  '曾肇',
#  '朱胜非',
#  '李光',
#  '李处耘',
#  '李宾王',
#  '李师中',
#  '李弥大',
#  '李氏(赵祯母)',
#  '李渭',
#  '李纲',
#  '李迪',
#  '李邦彦',
#  '李邴',
#  '杜衍',
#  '杨偕',
#  '杨徽之',
#  '杨愿',
#  '杨畏',
#  '杨覃',
#  '柳瑊',
#  '柴禹锡',
#  '江褒',
#  '汪伯彦',
#  '汪藻',
#  '沈季长',
#  '沈辽',
#  '洪皓',
#  '温益',
#  '潘美',
#  '潘良贵',
#  '狄青',
#  '王公彦',
#  '王安石',
#  '王安礼',
#  '王尧臣',
#  '王旦',
#  '王显',
#  '王珪',
#  '王畴',
#  '王祖道',
#  '王纶',
#  '王钦若',
#  '王震',
#  '王黼',
#  '皮公弼',
#  '石介',
#  '祖无择',
#  '种师道',
#  '秦桧',
#  '秦熺',
#  '程琳',
#  '程瑀',
#  '程颐',
#  '章惇',
#  '章綡',
#  '章縡',
#  '胡则',
#  '胡宗愈',
#  '胡宪',
#  '胡宿',
#  '胡瑗',
#  '胥偃',
#  '苏安世',
#  '苏舜钦',
#  '苏轼',
#  '苏辙',
#  '苗傅',
#  '范仲淹',
#  '范同',
#  '范如圭',
#  '范宗尹',
#  '范濬',
#  '范琼',
#  '范祖禹',
#  '范纯仁',
#  '范纯礼',
#  '范镇',
#  '萧服',
#  '蔡承禧',
#  '薛奎',
#  '薛弼',
#  '许将',
#  '贾昌朝',
#  '贾蕃',
#  '赵匡胤',
#  '赵抃',
#  '赵普',
#  '赵槩',
#  '赵玭',
#  '赵祯',
#  '赵顼',
#  '赵鼎',
#  '邓洵武',
#  '邓肃',
#  '邢焕',
#  '邵伯温',
#  '邹浩',
#  '郑侠',
#  '郑刚中',
#  '郑居中',
#  '郑獬',
#  '郑雍',
#  '郭知章',
#  '郭贽',
#  '陈尧佐',
#  '陈戬',
#  '陈执中',
#  '陈次升',
#  '陈瓘',
#  '陈若拙',
#  '韩世忠',
#  '韩忠彦',
#  '韩熙载',
#  '韩琦',
#  '韩缜',
#  '马伸',
#  '马知节',
#  '高氏(赵曙妻)',
#  '高琼',
#  '高登',
#  '高若讷',
#  '鲁宗道',
#  '黄庭坚',
#  '黄策'}

# %%
# !pip install matplotlib-venn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib-venn in c:\users\zky\appdata\roaming\python\python310\site-packages (0.11.9)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from matplotlib-venn) (1.23.5)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from matplotlib-venn) (3.7.0)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from matplotlib-venn) (1.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->matplotlib-venn) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->matplotlib-venn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->matplotlib-venn) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->matplotlib-venn) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->matplotlib-venn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->matplotlib-venn) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->matplotlib-venn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->matplotlib-venn) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)

# %%
import matplotlib_venn as venn

# %%
venn.venn3([officer,associate,kin],set_labels=('官员','关系人','亲戚'))

# %%
officer&associate&kin
# Out:
# {'曾布', '王安石', '王安礼', '章綡', '章縡', '苏轼', '苏辙', '范仲淹', '赵祯', '赵顼', '韩忠彦', '韩琦'}

# %%
relation.columns
# Out:
# Index(['Name', '姓名', 'Index year', 'Sex', 'Associate', '社会关系人姓名',
#        'Assoc. Index Year', 'Assoc. Sex', 'Association', '联系', 'Address', '籍贯',
#        'X', 'Y', 'Assoc. Address', '联系人籍贯', 'Assoc. X', 'Assoc. Y',
#        'Kinship Relation', '亲属关系', 'Kin Name', '亲戚姓名', 'Assoc. Kinship Rel.',
#        '关系人的亲属关系', 'Assoc. Kin Name', '关系人的亲戚姓名', 'Distance 距离', 'Person ID',
#        'Assoc ID'],
#       dtype='object')

# %%
relation.groupby('Index year')['姓名'].nunique().sort_values(ascending = False).idxmax()
# Out:
# 1008

# %%
realation.query("`Index year` == 1008")
# Out:
#             Name   姓名  Index year Sex      Associate 社会关系人姓名  \
# 230       Han Qi   韩琦        1008   M     Ouyang Xiu     欧阳修
# 281   Su Shunqin  苏舜钦        1008   M       Zhao Gai      赵槩
# 315      Di Qing   狄青        1008   M    Linghu Shan     令狐挻
# 351       Han Qi   韩琦        1008   M        Yin Zhu      尹洙
# 352       Han Qi   韩琦        1008   M         Hu Hui      胡恢
# 353       Han Qi   韩琦        1008   M         Zhu Zi      祝谘
# 428    Zhao Bian   赵抃        1008   M     Wang Anshi     王安石
# 449  Fan Zhen(2)   范镇        1008   M     Wang Anshi     王安石
# 484       Han Qi   韩琦        1008   M         Du Yan      杜衍
# 494  Fan Zhen(2)   范镇        1008   M  Zhao Cuizhong     赵粹中
#
#      Assoc. Index Year Assoc. Sex              Association      联系  ... 亲属关系  \
# 230             1007.0          M             Supported by  得到Y的支持  ...   未详
# 281              996.0          M             Supported by  得到Y的支持  ...   未详
# 315              992.0          M             Supported by  得到Y的支持  ...   未详
# 351             1001.0          M                Supported      支持  ...   未详
# 352                NaN          M                Supported      支持  ...   未详
# 353             1009.0          M                Supported      支持  ...   未详
# 428             1021.0          M  Disagreed with views of      不合  ...   未详
# 449             1021.0          M  Disagreed with views of      不合  ...   未详
# 484              978.0          M     Agreed with views of    政见趋同  ...   未详
# 494             1124.0          M     Agreed with views of    政见趋同  ...   未详
#
#       Kin Name  亲戚姓名  Assoc. Kinship Rel. 关系人的亲属关系 Assoc. Kin Name  关系人的亲戚姓名  \
# 230  Wei Xiang    未详                    U       未详       Wei Xiang        未详
# 281  Wei Xiang    未详                    U       未详       Wei Xiang        未详
# 315  Wei Xiang    未详                    U       未详       Wei Xiang        未详
# 351  Wei Xiang    未详                    U       未详       Wei Xiang        未详
# 352  Wei Xiang    未详                    U       未详       Wei Xiang        未详
# 353  Wei Xiang    未详                    U       未详       Wei Xiang        未详
# 428  Wei Xiang    未详                    U       未详       Wei Xiang        未详
# 449  Wei Xiang    未详                    U       未详       Wei Xiang        未详
# 484  Wei Xiang    未详                    U       未详       Wei Xiang        未详
# 494  Wei Xiang    未详                    U       未详       Wei Xiang        未详
#
#      Distance 距离 Person ID Assoc ID
# 230   197.511939       630     1384
# 281   144.556544      7064     8022
# 315   787.215427      8127    95228
# 351   238.859266       630     7104
# 352   606.780486       630    42912
# 353   187.398506       630    44409
# 428   268.653609       375     1762
# 449   714.252289      3279     1762
# 484   218.236050       630     1730
# 494   862.970327      3279    25203
#
# [10 rows x 29 columns]

# %%
relation.drop('Sex',axis=1)
# Out:
#                 Name   姓名  Index year       Associate 社会关系人姓名  \
# 0             An Dun   安惇        1042         Zou Hao      邹浩
# 1             An Dun   安惇        1042  Zhang Shiliang     张士良
# 2       Chen Jian(2)   陈戬        1081       Tong Guan      童贯
# 3           Cheng Yu   程瑀        1087          Wu Min      吴敏
# 4    Zhang Shangying  张商英        1043      Sima Guang     司马光
# ..               ...  ...         ...             ...     ...
# 501          Yu Jing   余靖        1000      Ouyang Xiu     欧阳修
# 502          Yu Jing   余靖        1000         Yin Zhu      尹洙
# 503       Kong Daofu  孔道辅         986        Yang Xie      杨偕
# 504      Liu Anshang  刘安上        1069      Shi Gongbi     石公弼
# 505        Han Xizai  韩熙载         902         Xu Xuan      徐铉
#
#      Assoc. Index Year Assoc. Sex           Association     联系   Address  ...  \
# 0               1060.0          M   Opposed or attacked  反对/攻讦   Qujiang  ...
# 1                  NaN          M   Opposed or attacked  反对/攻讦   Qujiang  ...
# 2               1054.0          M   Opposed or attacked  反对/攻讦    Songxi  ...
# 3               1087.0          M   Opposed or attacked  反对/攻讦   Fuliang  ...
# 4               1019.0          M   Opposed or attacked  反对/攻讦    Xinjin  ...
# ..                 ...        ...                   ...    ...       ...  ...
# 501             1007.0          M  Agreed with views of   政见趋同   Qujiang  ...
# 502             1001.0          M  Agreed with views of   政见趋同   Qujiang  ...
# 503              980.0          M  Agreed with views of   政见趋同  Xianyuan  ...
# 504             1061.0          M  Agreed with views of   政见趋同   Yongjia  ...
# 505              920.0          M  Agreed with views of   政见趋同    Beihai  ...
#
#     亲属关系   Kin Name  亲戚姓名 Assoc. Kinship Rel. 关系人的亲属关系  Assoc. Kin Name  \
# 0     未详  Wei Xiang    未详                   U       未详        Wei Xiang
# 1     未详  Wei Xiang    未详                   U       未详        Wei Xiang
# 2     未详  Wei Xiang    未详                   U       未详        Wei Xiang
# 3     未详  Wei Xiang    未详                   U       未详        Wei Xiang
# 4     未详  Wei Xiang    未详                   U       未详        Wei Xiang
# ..   ...        ...   ...                 ...      ...              ...
# 501   未详  Wei Xiang    未详                   U       未详        Wei Xiang
# 502   未详  Wei Xiang    未详                   U       未详        Wei Xiang
# 503   未详  Wei Xiang    未详                   U       未详        Wei Xiang
# 504   未详  Wei Xiang    未详                   U       未详        Wei Xiang
# 505   未详  Wei Xiang    未详                   U       未详        Wei Xiang
#
#      关系人的亲戚姓名  Distance 距离 Person ID Assoc ID
# 0          未详  1275.341259         1     3888
# 1          未详          NaN         1    25065
# 2          未详   910.189663        31     8124
# 3          未详   370.461638       128     8163
# 4          未详   868.170971       272     1488
# ..        ...          ...       ...      ...
# 501        未详  1066.098438     12319     1384
# 502        未详  1102.124909     12319     7104
# 503        未详   431.228735     15939     2003
# 504        未详   165.947261     17479    13417
# 505        未详   941.629297     94724    12236
#
# [506 rows x 28 columns]

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker

c = (
    Geo()
    .add_schema(maptype="china")
    .add("geo", [list(z) for z in zip(Faker.provinces, Faker.values())])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-基本示例")
    )
#     .render("geo_base.html")
    .render_notebook()
)
c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="b3d19b2e8649443ababe5043c3226ffa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_b3d19b2e8649443ababe5043c3226ffa = echarts.init(
#                     document.getElementById('b3d19b2e8649443ababe5043c3226ffa'), 'white', {renderer: 'canvas'});
#                 var option_b3d19b2e8649443ababe5043c3226ffa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c\u7701",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         137
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": [
#                         116.4,
#                         39.9,
#                         125
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": [
#                         121.47,
#                         31.23,
#                         33
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f\u7701",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         110
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         74
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f\u7701",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         61
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf\u7701",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         124
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Geo-\u57fa\u672c\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_b3d19b2e8649443ababe5043c3226ffa.setOption(option_b3d19b2e8649443ababe5043c3226ffa);
#         });
#     </script>

# %%
realation.columns
# Out:
# Index(['Name', '姓名', 'Index year', 'Sex', 'Associate', '社会关系人姓名',
#        'Assoc. Index Year', 'Assoc. Sex', 'Association', '联系', 'Address', '籍贯',
#        'X', 'Y', 'Assoc. Address', '联系人籍贯', 'Assoc. X', 'Assoc. Y',
#        'Kinship Relation', '亲属关系', 'Kin Name', '亲戚姓名', 'Assoc. Kinship Rel.',
#        '关系人的亲属关系', 'Assoc. Kin Name', '关系人的亲戚姓名', 'Distance 距离', 'Person ID',
#        'Assoc ID'],
#       dtype='object')

# %%
realation[['X','Y']].groupby(realation['籍贯']).first()
# Out:
#               X          Y
# 籍贯
# 上元   118.768990  32.052563
# 上蔡   114.226669  33.264837
# 上虞   120.973587  29.952654
# 下邽   109.509590  34.729103
# 东平府  116.299171  35.910343
# ..          ...        ...
# 雍邱   114.760660  34.495470
# 须城   116.282559  35.956072
# 高密   119.752564  36.385406
# 高邮   119.437332  32.790710
# 龙泉   119.120910  28.082565
#
# [112 rows x 2 columns]

# %%
jiguanxy = relation[['籍贯','X','Y']].groupby('籍贯').first()
jiguanxy
# Out:
#               X          Y
# 籍贯
# 上元   118.768990  32.052563
# 上蔡   114.226669  33.264837
# 上虞   120.973587  29.952654
# 下邽   109.509590  34.729103
# 东平府  116.299171  35.910343
# ..          ...        ...
# 雍邱   114.760660  34.495470
# 须城   116.282559  35.956072
# 高密   119.752564  36.385406
# 高邮   119.437332  32.790710
# 龙泉   119.120910  28.082565
#
# [112 rows x 2 columns]

# %%
jiguangy = relation.groupby('籍贯')['姓名'].nunique()
jiguangy
# Out:
# 籍贯
# 上元     2
# 上蔡     1
# 上虞     1
# 下邽     1
# 东平府    1
#       ..
# 雍邱     2
# 须城     1
# 高密     1
# 高邮     1
# 龙泉     1
# Name: 姓名, Length: 112, dtype: int64

# %%
a = pd.merge(jiguangy,jiguanxy,on='籍贯')
a
# Out:
#      姓名           X          Y
# 籍贯
# 上元    2  118.768990  32.052563
# 上蔡    1  114.226669  33.264837
# 上虞    1  120.973587  29.952654
# 下邽    1  109.509590  34.729103
# 东平府   1  116.299171  35.910343
# ..   ..         ...        ...
# 雍邱    2  114.760660  34.495470
# 须城    1  116.282559  35.956072
# 高密    1  119.752564  36.385406
# 高邮    1  119.437332  32.790710
# 龙泉    1  119.120910  28.082565
#
# [112 rows x 3 columns]

# %%
a.loc['上元',['X','Y']]
# Out:
# X    118.768990
# Y     32.052563
# Name: 上元, dtype: float64

# %%
dic = {}
for city in a.index.tolist():
    dic[city] = a.loc[city,['X','Y']].tolist()
dic
# Out:
# {'上元': [118.76899, 32.052563],
#  '上蔡': [114.226669, 33.264837],
#  '上虞': [120.973587, 29.952654],
#  '下邽': [109.50959, 34.729103],
#  '东平府': [116.2991715, 35.91034317],
#  '东明': [114.859356, 34.92438],
#  '丰城': [115.785782, 28.197754],
#  '临川': [116.351341, 27.984781],
#  '临海': [121.120598, 28.843132],
#  '丹徒': [119.4442902, 32.20648956],
#  '义乌': [120.071625, 29.300087],
#  '亳州': [115.7709045, 33.87929153],
#  '仙游': [118.68367, 25.36455727],
#  '仙源': [116.986059, 35.597553],
#  '元城': [115.146522, 36.275528],
#  '光化': [113.464426, 31.640304],
#  '分宁': [114.559631, 29.038708],
#  '北海': [119.106499, 36.702705],
#  '华阳': [104.077995, 30.650385],
#  '南丰': [116.52993, 27.214306],
#  '卢龙': [118.8619537, 39.87731934],
#  '双流': [103.923309, 30.579893],
#  '吉水': [115.132248, 27.214367],
#  '吴县': [120.618622, 31.31271],
#  '嘉兴': [120.753204, 30.767469],
#  '夏县': [111.220055, 35.137451],
#  '奉符': [117.126519, 36.182097],
#  '如皋': [120.558662, 32.384022],
#  '宁晋': [114.9153976, 37.62108612],
#  '安阳': [114.345497, 36.098343],
#  '安陆': [113.688919, 31.263714],
#  '宋城': [115.646072, 34.447662],
#  '宜兴': [119.814385, 31.363638],
#  '导江': [103.713741, 31.002649],
#  '崇安': [118.026779, 27.756025],
#  '平江': [113.574943, 28.709812],
#  '庐陵': [114.971275, 27.103239],
#  '建安': [118.323784, 27.038864],
#  '建阳': [118.10537, 27.33988],
#  '开化': [118.404884, 29.14485],
#  '开封': [114.34333, 34.785477],
#  '开封府': [114.34333, 34.785477],
#  '彭山': [103.869247, 30.200752],
#  '德兴': [117.580116, 28.953411],
#  '怀州': [112.9369888, 35.08930206],
#  '成纪': [105.7258, 34.5853],
#  '成都': [104.077995, 30.650385],
#  '新喻': [114.931137, 27.804075],
#  '新津': [103.810936, 30.423536],
#  '无锡': [120.297668, 31.574614],
#  '晋江': [118.589905, 24.909641],
#  '曲江': [113.603417, 24.810209],
#  '杭州': [120.1686249, 30.2941246],
#  '松溪': [118.774612, 27.528404],
#  '榆次': [112.744682, 37.678467],
#  '正平': [111.216148, 35.616409],
#  '武昌': [114.879906, 30.402718],
#  '武进': [119.952301, 31.782784],
#  '武陟': [113.3653565, 35.05608749],
#  '永嘉': [120.653221, 28.018291],
#  '永康': [120.025253, 28.897268],
#  '汝阴': [115.809013, 32.903057],
#  '江宁': [118.76899, 32.052563],
#  '江都': [119.437187, 32.39127],
#  '江陵': [112.190773, 30.350445],
#  '沙县': [117.781792, 26.39761],
#  '河阳': [112.785721, 34.840869],
#  '泉江': [114.505661, 26.327883],
#  '洛阳': [112.38263, 34.665276],
#  '济阴': [115.282862, 34.990951],
#  '浦城': [118.536255, 27.924686],
#  '浮梁': [117.236359, 29.382742],
#  '海陵': [119.91124, 32.495872],
#  '淮安': [119.141106, 33.502789],
#  '清江': [115.398987, 28.015566],
#  '清池': [117.024101, 38.209126],
#  '渠江': [106.631752, 30.47769],
#  '湖州': [120.0993118, 30.86496353],
#  '漳浦': [117.610733, 24.117096],
#  '濮阳': [115.078057, 35.650175],
#  '相州': [114.34549, 36.098343],
#  '眉山': [103.831459, 30.050497],
#  '祁门': [117.706978, 29.854147],
#  '祥符': [114.34333, 34.785477],
#  '福清': [119.381439, 25.727917],
#  '管城': [113.641312, 34.758076],
#  '莘县': [115.665085, 36.236708],
#  '营道': [111.590881, 25.531357],
#  '蓝田': [109.321556, 34.153698],
#  '虞城': [115.887953, 34.510823],
#  '襄邑': [115.065971, 34.430504],
#  '西安': [118.867645, 28.956821],
#  '西河': [111.77903, 37.263405],
#  '谯县': [115.770905, 33.879292],
#  '郿县': [107.796328, 34.478271],
#  '鄞县': [121.542656, 29.866316],
#  '鄱阳': [116.663833, 28.994167],
#  '金华': [119.649918, 29.104712],
#  '钱塘': [120.168625, 30.294125],
#  '长寿': [112.589256, 31.169827],
#  '长沙': [112.978134, 28.198198],
#  '长洲': [120.618622, 31.31271],
#  '长社': [113.819748, 34.031391],
#  '闻喜': [111.217209, 35.357723],
#  '闽县': [119.321577, 26.073954],
#  '阳曲': [112.736015, 38.08202],
#  '阳翟': [113.467056, 34.162491],
#  '雍邱': [114.76066, 34.49547],
#  '须城': [116.282559, 35.956072],
#  '高密': [119.752564, 36.385406],
#  '高邮': [119.437332, 32.79071],
#  '龙泉': [119.12091, 28.082565]}

# %%
import json
js = json.dumps(dic,ensure_ascii = False)
js
# Out:
# '{"上元": [118.76899, 32.052563], "上蔡": [114.226669, 33.264837], "上虞": [120.973587, 29.952654], "下邽": [109.50959, 34.729103], "东平府": [116.2991715, 35.91034317], "东明": [114.859356, 34.92438], "丰城": [115.785782, 28.197754], "临川": [116.351341, 27.984781], "临海": [121.120598, 28.843132], "丹徒": [119.4442902, 32.20648956], "义乌": [120.071625, 29.300087], "亳州": [115.7709045, 33.87929153], "仙游": [118.68367, 25.36455727], "仙源": [116.986059, 35.597553], "元城": [115.146522, 36.275528], "光化": [113.464426, 31.640304], "分宁": [114.559631, 29.038708], "北海": [119.106499, 36.702705], "华阳": [104.077995, 30.650385], "南丰": [116.52993, 27.214306], "卢龙": [118.8619537, 39.87731934], "双流": [103.923309, 30.579893], "吉水": [115.132248, 27.214367], "吴县": [120.618622, 31.31271], "嘉兴": [120.753204, 30.767469], "夏县": [111.220055, 35.137451], "奉符": [117.126519, 36.182097], "如皋": [120.558662, 32.384022], "宁晋": [114.9153976, 37.62108612], "安阳": [114.345497, 36.098343], "安陆": [113.688919, 31.263714], "宋城": [115.646072, 34.447662], "宜兴": [119.814385, 31.363638], "导江": [103.713741, 31.002649], "崇安": [118.026779, 27.756025], "平江": [113.574943, 28.709812], "庐陵": [114.971275, 27.103239], "建安": [118.323784, 27.038864], "建阳": [118.10537, 27.33988], "开化": [118.404884, 29.14485], "开封": [114.34333, 34.785477], "开封府": [114.34333, 34.785477], "彭山": [103.869247, 30.200752], "德兴": [117.580116, 28.953411], "怀州": [112.9369888, 35.08930206], "成纪": [105.7258, 34.5853], "成都": [104.077995, 30.650385], "新喻": [114.931137, 27.804075], "新津": [103.810936, 30.423536], "无锡": [120.297668, 31.574614], "晋江": [118.589905, 24.909641], "曲江": [113.603417, 24.810209], "杭州": [120.1686249, 30.2941246], "松溪": [118.774612, 27.528404], "榆次": [112.744682, 37.678467], "正平": [111.216148, 35.616409], "武昌": [114.879906, 30.402718], "武进": [119.952301, 31.782784], "武陟": [113.3653565, 35.05608749], "永嘉": [120.653221, 28.018291], "永康": [120.025253, 28.897268], "汝阴": [115.809013, 32.903057], "江宁": [118.76899, 32.052563], "江都": [119.437187, 32.39127], "江陵": [112.190773, 30.350445], "沙县": [117.781792, 26.39761], "河阳": [112.785721, 34.840869], "泉江": [114.505661, 26.327883], "洛阳": [112.38263, 34.665276], "济阴": [115.282862, 34.990951], "浦城": [118.536255, 27.924686], "浮梁": [117.236359, 29.382742], "海陵": [119.91124, 32.495872], "淮安": [119.141106, 33.502789], "清江": [115.398987, 28.015566], "清池": [117.024101, 38.209126], "渠江": [106.631752, 30.47769], "湖州": [120.0993118, 30.86496353], "漳浦": [117.610733, 24.117096], "濮阳": [115.078057, 35.650175], "相州": [114.34549, 36.098343], "眉山": [103.831459, 30.050497], "祁门": [117.706978, 29.854147], "祥符": [114.34333, 34.785477], "福清": [119.381439, 25.727917], "管城": [113.641312, 34.758076], "莘县": [115.665085, 36.236708], "营道": [111.590881, 25.531357], "蓝田": [109.321556, 34.153698], "虞城": [115.887953, 34.510823], "襄邑": [115.065971, 34.430504], "西安": [118.867645, 28.956821], "西河": [111.77903, 37.263405], "谯县": [115.770905, 33.879292], "郿县": [107.796328, 34.478271], "鄞县": [121.542656, 29.866316], "鄱阳": [116.663833, 28.994167], "金华": [119.649918, 29.104712], "钱塘": [120.168625, 30.294125], "长寿": [112.589256, 31.169827], "长沙": [112.978134, 28.198198], "长洲": [120.618622, 31.31271], "长社": [113.819748, 34.031391], "闻喜": [111.217209, 35.357723], "闽县": [119.321577, 26.073954], "阳曲": [112.736015, 38.08202], "阳翟": [113.467056, 34.162491], "雍邱": [114.76066, 34.49547], "须城": [116.282559, 35.956072], "高密": [119.752564, 36.385406], "高邮": [119.437332, 32.79071], "龙泉": [119.12091, 28.082565]}'

# %%
with open('./addr.json',mode='w') as f:
    json.dump(dic,f,ensure_ascii=False)

# %%
#复制官网原形，然后更改相应设置
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker
c = (
Geo(init_opts=opts.InitOpts(width='1200px',height='800px'))
.add_schema(maptype="china",is_roam=False)
.add_coordinate_json('./addr.json')
.add("官员人数",[list(z) for z in zip(a.index.tolist(),a['姓名'].values.tolist())])
.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
.set_global_opts(
visualmap_opts=opts.VisualMapOpts(),
title_opts=opts.TitleOpts(title="Geo-基本示例")
)
# .render("geo_base.html")
.render_notebook()
)
c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="d27a911942e04508af06601bd8cb8efa" style="width:1200px; height:800px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_d27a911942e04508af06601bd8cb8efa = echarts.init(
#                     document.getElementById('d27a911942e04508af06601bd8cb8efa'), 'white', {renderer: 'canvas'});
#                 var option_d27a911942e04508af06601bd8cb8efa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5b98\u5458\u4eba\u6570",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u4e0a\u5143",
#                     "value": [
#                         118.76899,
#                         32.052563,
#                         2
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u8521",
#                     "value": [
#                         114.226669,
#                         33.264837,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u865e",
#                     "value": [
#                         120.973587,
#                         29.952654,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u4e0b\u90bd",
#                     "value": [
#                         109.50959,
#                         34.729103,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u4e1c\u5e73\u5e9c",
#                     "value": [
#                         116.2991715,
#                         35.91034317,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u4e1c\u660e",
#                     "value": [
#                         114.859356,
#                         34.92438,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u4e30\u57ce",
#                     "value": [
#                         115.785782,
#                         28.197754,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u4e34\u5ddd",
#                     "value": [
#                         116.351341,
#                         27.984781,
#                         3
#                     ]
#                 },
#                 {
#                     "name": "\u4e34\u6d77",
#                     "value": [
#                         121.120598,
#                         28.843132,
#                         2
#                     ]
#                 },
#                 {
#                     "name": "\u4e39\u5f92",
#                     "value": [
#                         119.4442902,
#                         32.20648956,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u4e49\u4e4c",
#                     "value": [
#                         120.071625,
#                         29.300087,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u4eb3\u5dde",
#                     "value": [
#                         115.7709045,
#                         33.87929153,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u4ed9\u6e38",
#                     "value": [
#                         118.68367,
#                         25.36455727,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u4ed9\u6e90",
#                     "value": [
#                         116.986059,
#                         35.597553,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u5143\u57ce",
#                     "value": [
#                         115.146522,
#                         36.275528,
#                         3
#                     ]
#                 },
#                 {
#                     "name": "\u5149\u5316",
#                     "value": [
#                         113.464426,
#                         31.640304,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u5206\u5b81",
#                     "value": [
#                         114.559631,
#                         29.038708,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u6d77",
#                     "value": [
#                         119.106499,
#                         36.702705,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u534e\u9633",
#                     "value": [
#                         104.077995,
#                         30.650385,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4e30",
#                     "value": [
#                         116.52993,
#                         27.214306,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u5362\u9f99",
#                     "value": [
#                         118.8619537,
#                         39.87731934,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u53cc\u6d41",
#                     "value": [
#                         103.923309,
#                         30.579893,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u5409\u6c34",
#                     "value": [
#                         115.132248,
#                         27.214367,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u5434\u53bf",
#                     "value": [
#                         120.618622,
#                         31.31271,
#                         9
#                     ]
#                 },
#                 {
#                     "name": "\u5609\u5174",
#                     "value": [
#                         120.753204,
#                         30.767469,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u590f\u53bf",
#                     "value": [
#                         111.220055,
#                         35.137451,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u5949\u7b26",
#                     "value": [
#                         117.126519,
#                         36.182097,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u5982\u768b",
#                     "value": [
#                         120.558662,
#                         32.384022,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u5b81\u664b",
#                     "value": [
#                         114.9153976,
#                         37.62108612,
#                         1
