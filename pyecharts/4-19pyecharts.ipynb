# %%
import pyecharts
import pyecharts.options as opts
from pyecharts.charts import Line
from pyecharts.faker import Faker

# %%
# !pip install pyecharts
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyecharts in c:\users\zky\appdata\roaming\python\python310\site-packages (2.0.2)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from pyecharts) (3.1.2)
# Requirement already satisfied: prettytable in c:\users\zky\appdata\roaming\python\python310\site-packages (from pyecharts) (3.6.0)
# Requirement already satisfied: simplejson in c:\users\zky\appdata\roaming\python\python310\site-packages (from pyecharts) (3.18.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->pyecharts) (2.1.1)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prettytable->pyecharts) (0.2.5)

# %%
print(pyecharts.__version__)
# Out:
# 2.0.2

# %% [markdown]
# ### 折线图

# %%
import pandas as pd 
data1 = pd.read_excel('./超市.xlsx')
data1.head()
# Out:
#    行 ID            订单 ID       订单日期       发货日期 邮寄方式     客户 ID 客户名称   细分  城市  \
# 0     1  US-2018-1357144 2018-04-27 2018-04-29   二级  曾惠-14485   曾惠   公司  杭州
# 1     2  CN-2018-1973789 2018-06-15 2018-06-19  标准级  许安-10165   许安  消费者  内江
# 2     3  CN-2018-1973789 2018-06-15 2018-06-19  标准级  许安-10165   许安  消费者  内江
# 3     4  US-2018-3017568 2018-12-09 2018-12-13  标准级  宋良-17170   宋良   公司  镇江
# 4     5  CN-2017-2975416 2017-05-31 2017-06-02   二级  万兰-15730   万兰  消费者  汕头
#
#   省/自治区  国家  地区            产品 ID    类别  子类别                产品名称       销售额  数量  \
# 0    浙江  中国  华东  办公用-用品-10002717  办公用品   用品      Fiskars 剪刀, 蓝色   129.696   2
# 1    四川  中国  西南  办公用-信封-10004832  办公用品   信封  GlobeWeis 搭扣信封, 红色   125.440   2
# 2    四川  中国  西南  办公用-装订-10001505  办公用品  装订机  Cardinal 孔加固材料, 回收    31.920   2
# 3    江苏  中国  华东  办公用-用品-10003746  办公用品   用品    Kleencut 开信刀, 工业   321.216   4
# 4    广东  中国  中南  办公用-器具-10003452  办公用品   器具  KitchenAid 搅拌机, 黑色  1375.920   3
#
#     折扣       利润
# 0  0.4  -60.704
# 1  0.0   42.560
# 2  0.4    4.200
# 3  0.4  -27.104
# 4  0.0  550.200

# %%
data1.columns
# Out:
# Index(['行 ID', '订单 ID', '订单日期', '发货日期', '邮寄方式', '客户 ID', '客户名称', '细分', '城市',
#        '省/自治区', '国家', '地区', '产品 ID', '类别', '子类别', '产品名称', '销售额', '数量', '折扣',
#        '利润'],
#       dtype='object')

# %%
c = (
    Line() # 创建折线图对象
    .add_xaxis(Faker.choose()) # 添加X轴数据
    .add_yaxis("商家A", Faker.values()) # 添加Y轴数据
    .add_yaxis("商家B", Faker.values()) # 添加Y轴数据
    .set_global_opts(title_opts = opts.TitleOpts(title="Line-基本⽰例")) 
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="83b15d3ddad44dbda7346157499f502a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_83b15d3ddad44dbda7346157499f502a = echarts.init(
#                     document.getElementById('83b15d3ddad44dbda7346157499f502a'), 'white', {renderer: 'canvas'});
#                 var option_83b15d3ddad44dbda7346157499f502a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     88
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     144
#                 ],
#                 [
#                     "\u8001\u864e",
#                     101
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     84
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     63
#                 ],
#                 [
#                     "\u718a\u732b",
#                     48
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     133
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     73
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     135
#                 ],
#                 [
#                     "\u8001\u864e",
#                     84
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     28
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     103
#                 ],
#                 [
#                     "\u718a\u732b",
#                     60
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     103
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "Line-\u57fa\u672c\u2f70\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_83b15d3ddad44dbda7346157499f502a.setOption(option_83b15d3ddad44dbda7346157499f502a);
#         });
#     </script>

# %%
data1['下单年月_data'] = data1['订单日期'].dt.strftime('%Y-%m')
data1
# Out:
#        行 ID            订单 ID       订单日期       发货日期 邮寄方式     客户 ID 客户名称   细分  \
# 0         1  US-2018-1357144 2018-04-27 2018-04-29   二级  曾惠-14485   曾惠   公司
# 1         2  CN-2018-1973789 2018-06-15 2018-06-19  标准级  许安-10165   许安  消费者
# 2         3  CN-2018-1973789 2018-06-15 2018-06-19  标准级  许安-10165   许安  消费者
# 3         4  US-2018-3017568 2018-12-09 2018-12-13  标准级  宋良-17170   宋良   公司
# 4         5  CN-2017-2975416 2017-05-31 2017-06-02   二级  万兰-15730   万兰  消费者
# ...     ...              ...        ...        ...  ...       ...  ...  ...
# 9954   9996  CN-2018-4318875 2018-05-28 2018-06-02  标准级  巩光-13435   巩光  消费者
# 9955   9997  CN-2018-4318875 2018-05-28 2018-06-02  标准级  巩光-13435   巩光  消费者
# 9956   9998  CN-2018-4318875 2018-05-28 2018-06-02  标准级  巩光-13435   巩光  消费者
# 9957   9999  CN-2018-4318875 2018-05-28 2018-06-02  标准级  巩光-13435   巩光  消费者
# 9958  10000  CN-2015-3557528 2015-12-02 2015-12-06  标准级  陈忠-11470   陈忠   公司
#
#       城市 省/自治区  ...  地区            产品 ID    类别  子类别                产品名称  \
# 0     杭州    浙江  ...  华东  办公用-用品-10002717  办公用品   用品      Fiskars 剪刀, 蓝色
# 1     内江    四川  ...  西南  办公用-信封-10004832  办公用品   信封  GlobeWeis 搭扣信封, 红色
# 2     内江    四川  ...  西南  办公用-装订-10001505  办公用品  装订机  Cardinal 孔加固材料, 回收
# 3     镇江    江苏  ...  华东  办公用-用品-10003746  办公用品   用品    Kleencut 开信刀, 工业
# 4     汕头    广东  ...  中南  办公用-器具-10003452  办公用品   器具  KitchenAid 搅拌机, 黑色
# ...   ..   ...  ...  ..              ...   ...  ...                 ...
# 9954  义乌    浙江  ...  华东   技术-配件-10003923    技术   配件     SanDisk 记忆卡, 实惠
# 9955  义乌    浙江  ...  华东  办公用-收纳-10003383  办公用品  收纳具         Eldon 盘, 蓝色
# 9956  义乌    浙江  ...  华东   家具-椅子-10002448    家具   椅子       SAFCO 折叠椅, 红色
# 9957  义乌    浙江  ...  华东   技术-配件-10002808    技术   配件          罗技 路由器, 耐用
# 9958  温州    浙江  ...  华东  办公用-器具-10002023  办公用品   器具     Breville 冰箱, 白色
#
#            销售额  数量   折扣        利润  下单年月_data
# 0      129.696   2  0.4   -60.704    2018-04
# 1      125.440   2  0.0    42.560    2018-06
# 2       31.920   2  0.4     4.200    2018-06
# 3      321.216   4  0.4   -27.104    2018-12
# 4     1375.920   3  0.0   550.200    2017-05
# ...        ...  ..  ...       ...        ...
# 9954   944.244   3  0.4  -314.916    2018-05
# 9955   447.720   2  0.0    35.560    2018-05
# 9956   239.988   1  0.4   -88.032    2018-05
# 9957  4851.588   7  0.4 -1617.392    2018-05
# 9958  7244.580   5  0.4 -3501.820    2015-12
#
# [9959 rows x 21 columns]

# %% [markdown]
# ### 需求：按年月看销售额趋势分析

# %%
data2 = data1.groupby('下单年月_data')['销售额'].sum()
data2
# Out:
# 下单年月_data
# 2015-01    231597.618
# 2015-02    104936.370
# 2015-03    167173.727
# 2015-04     96052.852
# 2015-05    232199.107
# 2015-06    339729.698
# 2015-07    140050.918
# 2015-08    356128.507
# 2015-09    320606.167
# 2015-10    283747.289
# 2015-11    342142.150
# 2015-12    316692.012
# 2016-01    173124.539
# 2016-02    117715.500
# 2016-03    194867.505
# 2016-04    128719.248
# 2016-05    428335.747
# 2016-06    343329.728
# 2016-07    178725.022
# 2016-08    425111.897
# 2016-09    315921.340
# 2016-10    360630.032
# 2016-11    408399.117
# 2016-12    357039.788
# 2017-01    178402.217
# 2017-02    190255.562
# 2017-03    207813.872
# 2017-04    220115.721
# 2017-05    399122.290
# 2017-06    442849.645
# 2017-07    224137.263
# 2017-08    443244.298
# 2017-09    463353.072
# 2017-10    484792.973
# 2017-11    526724.912
# 2017-12    462728.035
# 2018-01    222862.829
# 2018-02    285475.428
# 2018-03    399711.781
# 2018-04    333398.317
# 2018-05    632800.350
# 2018-06    565523.427
# 2018-07    340308.682
# 2018-08    588746.354
# 2018-09    502799.255
# 2018-10    577450.321
# 2018-11    468822.543
# 2018-12    544539.100
# Name: 销售额, dtype: float64

# %% [markdown]
# ### 可视化

# %%
x = data2.index.tolist()
c = (
    Line() # 创建折线图对象
    .add_xaxis(data2.index.tolist()) # 添加X轴数据
    .add_yaxis("总销售额", data2) # 添加Y轴数据
    .set_global_opts(
        # 设置 图例 显示 False
        legend_opts=opts.LegendOpts(is_show=False),
        # 设置 标题 和 标题居中
        title_opts = opts.TitleOpts(title="销售额趋势",pos_left='center'),
        # 设置x轴名称 和 大小
        xaxis_opts=opts.AxisOpts(name='日期',axislabel_opts={"rotate":45},name_textstyle_opts=opts.TextStyleOpts(font_size=20)),
        # 设置y轴名称 和 大小
        yaxis_opts=opts.AxisOpts(name='销售额',name_textstyle_opts=opts.TextStyleOpts(font_size=20))
        ) 
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5869999703014d03906a905bf05ff561" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5869999703014d03906a905bf05ff561 = echarts.init(
#                     document.getElementById('5869999703014d03906a905bf05ff561'), 'white', {renderer: 'canvas'});
#                 var option_5869999703014d03906a905bf05ff561 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u603b\u9500\u552e\u989d",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2015-01",
#                     231597.618
#                 ],
#                 [
#                     "2015-02",
#                     104936.37
#                 ],
#                 [
#                     "2015-03",
#                     167173.727
#                 ],
#                 [
#                     "2015-04",
#                     96052.852
#                 ],
#                 [
#                     "2015-05",
#                     232199.107
#                 ],
#                 [
#                     "2015-06",
#                     339729.69800000003
#                 ],
#                 [
#                     "2015-07",
#                     140050.918
#                 ],
#                 [
#                     "2015-08",
#                     356128.507
#                 ],
#                 [
#                     "2015-09",
#                     320606.167
#                 ],
#                 [
#                     "2015-10",
#                     283747.289
#                 ],
#                 [
#                     "2015-11",
#                     342142.15
#                 ],
#                 [
#                     "2015-12",
#                     316692.012
#                 ],
#                 [
#                     "2016-01",
#                     173124.539
#                 ],
#                 [
#                     "2016-02",
#                     117715.5
#                 ],
#                 [
#                     "2016-03",
#                     194867.505
#                 ],
#                 [
#                     "2016-04",
#                     128719.248
#                 ],
#                 [
#                     "2016-05",
#                     428335.747
#                 ],
#                 [
#                     "2016-06",
#                     343329.728
#                 ],
#                 [
#                     "2016-07",
#                     178725.022
#                 ],
#                 [
#                     "2016-08",
#                     425111.897
#                 ],
#                 [
#                     "2016-09",
#                     315921.34
#                 ],
#                 [
#                     "2016-10",
#                     360630.032
#                 ],
#                 [
#                     "2016-11",
#                     408399.117
#                 ],
#                 [
#                     "2016-12",
#                     357039.788
#                 ],
#                 [
#                     "2017-01",
#                     178402.217
#                 ],
#                 [
#                     "2017-02",
#                     190255.562
#                 ],
#                 [
#                     "2017-03",
#                     207813.872
#                 ],
#                 [
#                     "2017-04",
#                     220115.721
#                 ],
#                 [
#                     "2017-05",
#                     399122.29
#                 ],
#                 [
#                     "2017-06",
#                     442849.645
#                 ],
#                 [
#                     "2017-07",
#                     224137.263
#                 ],
#                 [
#                     "2017-08",
#                     443244.298
#                 ],
#                 [
#                     "2017-09",
#                     463353.072
#                 ],
#                 [
#                     "2017-10",
#                     484792.973
#                 ],
#                 [
#                     "2017-11",
#                     526724.912
#                 ],
#                 [
#                     "2017-12",
#                     462728.035
#                 ],
#                 [
#                     "2018-01",
#                     222862.829
#                 ],
#                 [
#                     "2018-02",
#                     285475.428
#                 ],
#                 [
#                     "2018-03",
#                     399711.781
#                 ],
#                 [
#                     "2018-04",
#                     333398.317
#                 ],
#                 [
#                     "2018-05",
#                     632800.35
#                 ],
#                 [
#                     "2018-06",
#                     565523.427
#                 ],
#                 [
#                     "2018-07",
#                     340308.682
#                 ],
#                 [
#                     "2018-08",
#                     588746.354
#                 ],
#                 [
#                     "2018-09",
#                     502799.255
#                 ],
#                 [
#                     "2018-10",
#                     577450.321
#                 ],
#                 [
#                     "2018-11",
#                     468822.543
#                 ],
#                 [
#                     "2018-12",
#                     544539.1
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u603b\u9500\u552e\u989d"
#             ],
#             "selected": {
#                 "\u603b\u9500\u552e\u989d": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize"

# %% [markdown]
# ### 面积图 原生

# %% [markdown]
# #### 需求：销售额和利润月度走势

# %%
data3 = data1.groupby('下单年月_data').agg({'销售额':'sum','利润':'sum'})
data3
# Out:
#                   销售额         利润
# 下单年月_data
# 2015-01    231597.618  37095.338
# 2015-02    104936.370  19972.890
# 2015-03    167173.727  18748.247
# 2015-04     96052.852  16653.112
# 2015-05    232199.107  23984.947
# 2015-06    339729.698  39157.118
# 2015-07    140050.918  11800.698
# 2015-08    356128.507  66818.087
# 2015-09    320606.167  23833.187
# 2015-10    283747.289  31483.529
# 2015-11    342142.150  42611.870
# 2015-12    316692.012  40852.252
# 2016-01    173124.539  36667.379
# 2016-02    117715.500   4729.340
# 2016-03    194867.505  26773.705
# 2016-04    128719.248  23989.448
# 2016-05    428335.747  68972.827
# 2016-06    343329.728  41615.028
# 2016-07    178725.022  25140.822
# 2016-08    425111.897  62763.897
# 2016-09    315921.340  40086.200
# 2016-10    360630.032  33097.652
# 2016-11    408399.117  62095.817
# 2016-12    357039.788  45538.108
# 2017-01    178402.217  23788.877
# 2017-02    190255.562  21820.162
# 2017-03    207813.872  39307.212
# 2017-04    220115.721  43246.721
# 2017-05    399122.290  55145.930
# 2017-06    442849.645  47280.345
# 2017-07    224137.263  26634.783
# 2017-08    443244.298  80355.338
# 2017-09    463353.072  61052.852
# 2017-10    484792.973  64715.413
# 2017-11    526724.912  66426.612
# 2017-12    462728.035  92168.755
# 2018-01    222862.829  33526.269
# 2018-02    285475.428  34466.908
# 2018-03    399711.781  56542.521
# 2018-04    333398.317  32704.077
# 2018-05    632800.350  68430.670
# 2018-06    565523.427  81670.267
# 2018-07    340308.682  58861.922
# 2018-08    588746.354  55773.074
# 2018-09    502799.255  80341.275
# 2018-10    577450.321  72686.621
# 2018-11    468822.543  31554.383
# 2018-12    544539.100  74556.440

# %%
x = data3.index.tolist()
y1 = data3['销售额'].tolist()
y2 = data3['利润'].tolist()

# %%
c = (
    Line()
    .add_xaxis(x) 
    # 添加Y1轴数据
    .add_yaxis(
        "总销售额",
        y1,
        areastyle_opts = opts.AreaStyleOpts(opacity = 0.5,color='#C7ECEE'),
        is_smooth = True
        ) 
    # 添加Y2轴数据
    .add_yaxis(
        "总销售额", 
        y2,
        areastyle_opts = opts.AreaStyleOpts(opacity = 0.5),
        is_smooth = True
        ) 
    .set_global_opts(
        # 设置 图例 显示 False
        legend_opts=opts.LegendOpts(is_show=False),
        # 设置 标题 和 标题居中
        title_opts = opts.TitleOpts(title="销售额趋势",pos_left='center'),
        # 设置x轴名称 和 大小
        xaxis_opts=opts.AxisOpts(name='日期',axislabel_opts={"rotate":45},name_textstyle_opts=opts.TextStyleOpts(font_size=20)),
        # 设置y轴名称 和 大小
        yaxis_opts=opts.AxisOpts(name='价格',name_textstyle_opts=opts.TextStyleOpts(font_size=20))
        ) 
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="552b962f3d21490eb7cbe7667057558e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_552b962f3d21490eb7cbe7667057558e = echarts.init(
#                     document.getElementById('552b962f3d21490eb7cbe7667057558e'), 'white', {renderer: 'canvas'});
#                 var option_552b962f3d21490eb7cbe7667057558e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u603b\u9500\u552e\u989d",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2015-01",
#                     231597.618
#                 ],
#                 [
#                     "2015-02",
#                     104936.37
#                 ],
#                 [
#                     "2015-03",
#                     167173.727
#                 ],
#                 [
#                     "2015-04",
#                     96052.852
#                 ],
#                 [
#                     "2015-05",
#                     232199.107
#                 ],
#                 [
#                     "2015-06",
#                     339729.69800000003
#                 ],
#                 [
#                     "2015-07",
#                     140050.918
#                 ],
#                 [
#                     "2015-08",
#                     356128.507
#                 ],
#                 [
#                     "2015-09",
#                     320606.167
#                 ],
#                 [
#                     "2015-10",
#                     283747.289
#                 ],
#                 [
#                     "2015-11",
#                     342142.15
#                 ],
#                 [
#                     "2015-12",
#                     316692.012
#                 ],
#                 [
#                     "2016-01",
#                     173124.539
#                 ],
#                 [
#                     "2016-02",
#                     117715.5
#                 ],
#                 [
#                     "2016-03",
#                     194867.505
#                 ],
#                 [
#                     "2016-04",
#                     128719.248
#                 ],
#                 [
#                     "2016-05",
#                     428335.747
#                 ],
#                 [
#                     "2016-06",
#                     343329.728
#                 ],
#                 [
#                     "2016-07",
#                     178725.022
#                 ],
#                 [
#                     "2016-08",
#                     425111.897
#                 ],
#                 [
#                     "2016-09",
#                     315921.34
#                 ],
#                 [
#                     "2016-10",
#                     360630.032
#                 ],
#                 [
#                     "2016-11",
#                     408399.117
#                 ],
#                 [
#                     "2016-12",
#                     357039.788
#                 ],
#                 [
#                     "2017-01",
#                     178402.217
#                 ],
#                 [
#                     "2017-02",
#                     190255.562
#                 ],
#                 [
#                     "2017-03",
#                     207813.872
#                 ],
#                 [
#                     "2017-04",
#                     220115.721
#                 ],
#                 [
#                     "2017-05",
#                     399122.29
#                 ],
#                 [
#                     "2017-06",
#                     442849.645
#                 ],
#                 [
#                     "2017-07",
#                     224137.263
#                 ],
#                 [
#                     "2017-08",
#                     443244.298
#                 ],
#                 [
#                     "2017-09",
#                     463353.072
#                 ],
#                 [
#                     "2017-10",
#                     484792.973
#                 ],
#                 [
#                     "2017-11",
#                     526724.912
#                 ],
#                 [
#                     "2017-12",
#                     462728.035
#                 ],
#                 [
#                     "2018-01",
#                     222862.829
#                 ],
#                 [
#                     "2018-02",
#                     285475.428
#                 ],
#                 [
#                     "2018-03",
#                     399711.781
#                 ],
#                 [
#                     "2018-04",
#                     333398.317
#                 ],
#                 [
#                     "2018-05",
#                     632800.35
#                 ],
#                 [
#                     "2018-06",
#                     565523.427
#                 ],
#                 [
#                     "2018-07",
#                     340308.682
#                 ],
#                 [
#                     "2018-08",
#                     588746.354
#                 ],
#                 [
#                     "2018-09",
#                     502799.255
#                 ],
#                 [
#                     "2018-10",
#                     577450.321
#                 ],
#                 [
#                     "2018-11",
#                     468822.543
#                 ],
#                 [
#                     "2018-12",
#                     544539.1
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5,
#                 "color": "#C7ECEE"
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u603b\u9500\u552e\u989d",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2015-01",
#                     37095.337999999996
#                 ],
#                 [
#                     "2015-02",
#                     19972.89
#                 ],
#                 [
#                     "2015-03",
#                     18748.247
#                 ],
#                 [
#                     "2015-04",
#                     16653.112
#                 ],
#                 [
#                     "2015-05",
#                     23984.947
#                 ],
#                 [
#                     "2015-06",
#                     39157.118
#                 ],
#                 [
#                     "2015-07",
#                     11800.697999999999
#                 ],
#                 [
#                     "2015-08",
#                     66818.087
#                 ],
#                 [
#                     "2015-09",
#                     23833.186999999998
#                 ],
#                 [
#                     "2015-10",
#                     31483.529
#                 ],
#                 [

# %%
c = (
    Line() # 创建折线图对象
    .add_xaxis(x) 
    # 添加Y1轴数据
    .add_yaxis(
        "总销售额",
        y1,
        areastyle_opts = opts.AreaStyleOpts(opacity = 0.5,color='#F7DC6F'),
        is_smooth = True
        ) 
    # 添加Y2轴数据
    .add_yaxis(
        "利润", 
        y2,
        areastyle_opts = opts.AreaStyleOpts(opacity = 0.5),
        is_smooth = True
        ) 
    .set_global_opts(
        # 设置 图例 显示 False
        legend_opts=opts.LegendOpts(pos_top='5%', pos_right='5%'),
        # 设置 标题 和 标题居中
        title_opts = opts.TitleOpts(title="销售额趋势",pos_left='center'),
        # 设置x轴名称 和 大小
        xaxis_opts=opts.AxisOpts(name='日期',axislabel_opts={"rotate":45},name_textstyle_opts=opts.TextStyleOpts(font_size=20)),
        # 设置y轴名称 和 大小
        yaxis_opts=opts.AxisOpts(name='价格',name_textstyle_opts=opts.TextStyleOpts(font_size=20))
        ) 
    .set_series_opts(
        # 不显示数值标签
        label_opts=opts.LabelOpts(is_show=False)
        )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="87db998b155147959cdbddf9ca73ab16" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_87db998b155147959cdbddf9ca73ab16 = echarts.init(
#                     document.getElementById('87db998b155147959cdbddf9ca73ab16'), 'white', {renderer: 'canvas'});
#                 var option_87db998b155147959cdbddf9ca73ab16 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u603b\u9500\u552e\u989d",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2015-01",
#                     231597.618
#                 ],
#                 [
#                     "2015-02",
#                     104936.37
#                 ],
#                 [
#                     "2015-03",
#                     167173.727
#                 ],
#                 [
#                     "2015-04",
#                     96052.852
#                 ],
#                 [
#                     "2015-05",
#                     232199.107
#                 ],
#                 [
#                     "2015-06",
#                     339729.69800000003
#                 ],
#                 [
#                     "2015-07",
#                     140050.918
#                 ],
#                 [
#                     "2015-08",
#                     356128.507
#                 ],
#                 [
#                     "2015-09",
#                     320606.167
#                 ],
#                 [
#                     "2015-10",
#                     283747.289
#                 ],
#                 [
#                     "2015-11",
#                     342142.15
#                 ],
#                 [
#                     "2015-12",
#                     316692.012
#                 ],
#                 [
#                     "2016-01",
#                     173124.539
#                 ],
#                 [
#                     "2016-02",
#                     117715.5
#                 ],
#                 [
#                     "2016-03",
#                     194867.505
#                 ],
#                 [
#                     "2016-04",
#                     128719.248
#                 ],
#                 [
#                     "2016-05",
#                     428335.747
#                 ],
#                 [
#                     "2016-06",
#                     343329.728
#                 ],
#                 [
#                     "2016-07",
#                     178725.022
#                 ],
#                 [
#                     "2016-08",
#                     425111.897
#                 ],
#                 [
#                     "2016-09",
#                     315921.34
#                 ],
#                 [
#                     "2016-10",
#                     360630.032
#                 ],
#                 [
#                     "2016-11",
#                     408399.117
#                 ],
#                 [
#                     "2016-12",
#                     357039.788
#                 ],
#                 [
#                     "2017-01",
#                     178402.217
#                 ],
#                 [
#                     "2017-02",
#                     190255.562
#                 ],
#                 [
#                     "2017-03",
#                     207813.872
#                 ],
#                 [
#                     "2017-04",
#                     220115.721
#                 ],
#                 [
#                     "2017-05",
#                     399122.29
#                 ],
#                 [
#                     "2017-06",
#                     442849.645
#                 ],
#                 [
#                     "2017-07",
#                     224137.263
#                 ],
#                 [
#                     "2017-08",
#                     443244.298
#                 ],
#                 [
#                     "2017-09",
#                     463353.072
#                 ],
#                 [
#                     "2017-10",
#                     484792.973
#                 ],
#                 [
#                     "2017-11",
#                     526724.912
#                 ],
#                 [
#                     "2017-12",
#                     462728.035
#                 ],
#                 [
#                     "2018-01",
#                     222862.829
#                 ],
#                 [
#                     "2018-02",
#                     285475.428
#                 ],
#                 [
#                     "2018-03",
#                     399711.781
#                 ],
#                 [
#                     "2018-04",
#                     333398.317
#                 ],
#                 [
#                     "2018-05",
#                     632800.35
#                 ],
#                 [
#                     "2018-06",
#                     565523.427
#                 ],
#                 [
#                     "2018-07",
#                     340308.682
#                 ],
#                 [
#                     "2018-08",
#                     588746.354
#                 ],
#                 [
#                     "2018-09",
#                     502799.255
#                 ],
#                 [
#                     "2018-10",
#                     577450.321
#                 ],
#                 [
#                     "2018-11",
#                     468822.543
#                 ],
#                 [
#                     "2018-12",
#                     544539.1
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5,
#                 "color": "#F7DC6F"
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5229\u6da6",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2015-01",
#                     37095.337999999996
#                 ],
#                 [
#                     "2015-02",
#                     19972.89
#                 ],
#                 [
#                     "2015-03",
#                     18748.247
#                 ],
#                 [
#                     "2015-04",
#                     16653.112
#                 ],
#                 [
#                     "2015-05",
#                     23984.947
#                 ],
#                 [
#                     "2015-06",
#                     39157.118
#                 ],
#                 [
#                     "2015-07",
#                     11800.697999999999
#                 ],
#                 [
#                     "2015-08",
#                     66818.087
#                 ],
#                 [
#                     "2015-09",

# %% [markdown]
# ### 柱形图 原生

# %% [markdown]
# #### 需求：看不同地区的销售额对比分析

# %%
data4 = data1.groupby('地区')['销售额'].sum()
data4 = pd.DataFrame(data4)
data4
# Out:
#             销售额
# 地区
# 东北  2681567.469
# 中南  4137415.093
# 华东  4684506.442
# 华北  2447301.017
# 西北   815039.596
# 西南  1303124.508

# %% [markdown]
# ##### 可视化

# %%
# 导入 柱形图
from pyecharts.charts import Bar

# x的取值
x = data4.index.tolist()  
# y的取值
y = data4['销售额'].tolist()
c = (
    Bar()
    # 设置 x
    .add_xaxis(x)
    # 设置 y
    .add_yaxis("销售额", y)
    .set_global_opts(title_opts=opts.TitleOpts(title="不同地区的销售额对比分析", subtitle="没有副标题"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="441343edccd64d3cb35d8c1073e5d179" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_441343edccd64d3cb35d8c1073e5d179 = echarts.init(
#                     document.getElementById('441343edccd64d3cb35d8c1073e5d179'), 'white', {renderer: 'canvas'});
#                 var option_441343edccd64d3cb35d8c1073e5d179 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9500\u552e\u989d",
#             "legendHoverLink": true,
#             "data": [
#                 2681567.469,
#                 4137415.093,
#                 4684506.442,
#                 2447301.017,
#                 815039.596,
#                 1303124.508
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u552e\u989d"
#             ],
#             "selected": {
#                 "\u9500\u552e\u989d": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e1c\u5317",
#                 "\u4e2d\u5357",
#                 "\u534e\u4e1c",
#                 "\u534e\u5317",
#                 "\u897f\u5317",
#                 "\u897f\u5357"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u4e0d\u540c\u5730\u533a\u7684\u9500\u552e\u989d\u5bf9\u6bd4\u5206\u6790",
#             "target": "blank",
#             "subtext": "\u6ca1\u6709\u526f\u6807\u9898",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_441343edccd64d3cb35d8c1073e5d179.setOption(option_441343edccd64d3cb35d8c1073e5d179);
#         });
#     </script>

# %% [markdown]
# #### 需求：不同地区不同类别销售额对比分析

# %% [markdown]
# ###### 取数

# %%
data5 = data1.groupby(['地区','类别'])['销售额'].sum()
data5 = pd.DataFrame(data5).unstack()
data5
# Out:
# 类别         办公用品           家具           技术
# 地区
# 东北   824673.052   920698.401   936196.016
# 中南  1270911.264  1399928.201  1466575.628
# 华东  1408628.592  1676224.130  1599653.720
# 华北   745813.516   919743.937   781743.564
# 西北   267870.792   316212.428   230956.376
# 西南   347692.576   501533.732   453898.200

# %% [markdown]
# ##### 原生堆叠

# %%
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values(), stack="stack1")
    .add_yaxis("商家B", Faker.values(), stack="stack1")
    .add_yaxis("商家C", Faker.values())
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar-堆叠数据（部分）"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4493366210914a378ce9dd6d4aca8dfc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4493366210914a378ce9dd6d4aca8dfc = echarts.init(
#                     document.getElementById('4493366210914a378ce9dd6d4aca8dfc'), 'white', {renderer: 'canvas'});
#                 var option_4493366210914a378ce9dd6d4aca8dfc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 111,
#                 32,
#                 44,
#                 127,
#                 71,
#                 145,
#                 59
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 89,
#                 113,
#                 121,
#                 101,
#                 94,
#                 93,
#                 60
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "legendHoverLink": true,
#             "data": [
#                 92,
#                 150,
#                 39,
#                 145,
#                 133,
#                 22,
#                 49
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "Bar-\u5806\u53e0\u6570\u636e\uff08\u90e8\u5206\uff09",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_4493366210914a378ce9dd6d4aca8dfc.setOption(option_4493366210914a378ce9dd6d4aca8dfc);
#         });
#     </script>

# %%
data5 = data1.groupby(['地区','类别'])['销售额'].sum()
data5 = pd.DataFrame(data5)
data5
# Out:
# 类别         办公用品           家具           技术
# 地区
# 东北   824673.052   920698.401   936196.016
# 中南  1270911.264  1399928.201  1466575.628
# 华东  1408628.592  1676224.130  1599653.720
# 华北   745813.516   919743.937   781743.564
# 西北   267870.792   316212.428   230956.376
# 西南   347692.576   501533.732   453898.200

# %%
x = data5.index.tolist()
y1 = data5['销售额']['办公用品'].tolist()
y2 = data5['销售额']['家具'].tolist()
y3 = data5['销售额']['技术'].tolist()

# %%
from pyecharts.charts import Bar
c = (
    Bar()
    .add_xaxis(x)
    .add_yaxis("办公用品", y1, stack="stack1")  # y1  stack="stack1" stack1 是让这仨y堆到 这叫stack1 的柱子上
    .add_yaxis("家具", y2, stack="stack1")   # y2
    .add_yaxis("技术", y3, stack="stack1")   # y3
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar-堆叠数据（部分）"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a14261bc2f444dccb5773c46bf6c7b84" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a14261bc2f444dccb5773c46bf6c7b84 = echarts.init(
#                     document.getElementById('a14261bc2f444dccb5773c46bf6c7b84'), 'white', {renderer: 'canvas'});
#                 var option_a14261bc2f444dccb5773c46bf6c7b84 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u529e\u516c\u7528\u54c1",
#             "legendHoverLink": true,
#             "data": [
#                 824673.052,
#                 1270911.264,
#                 1408628.592,
#                 745813.5160000001,
#                 267870.792,
#                 347692.576
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5bb6\u5177",
#             "legendHoverLink": true,
#             "data": [
#                 920698.401,
#                 1399928.201,
#                 1676224.13,
#                 919743.937,
#                 316212.428,
#                 501533.732
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6280\u672f",
#             "legendHoverLink": true,
#             "data": [
#                 936196.016,
#                 1466575.628,
#                 1599653.72,
#                 781743.564,
#                 230956.376,
#                 453898.2
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u529e\u516c\u7528\u54c1",
#                 "\u5bb6\u5177",
#                 "\u6280\u672f"
#             ],
#             "selected": {
#                 "\u529e\u516c\u7528\u54c1": true,
#                 "\u5bb6\u5177": true,
#                 "\u6280\u672f": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e1c\u5317",
#                 "\u4e2d\u5357",
#                 "\u534e\u4e1c",
#                 "\u534e\u5317",
#                 "\u897f\u5317",
#                 "\u897f\u5357"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "Bar-\u5806\u53e0\u6570\u636e\uff08\u90e8\u5206\uff09",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_a14261bc2f444dccb5773c46bf6c7b84.setOption(option_a14261bc2f444dccb5773c46bf6c7b84);
#         });
#     </script>
