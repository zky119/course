# %%
import numpy as np
import pandas as pd
from pyecharts.globals import CurrentConfig, NotebookType

# 配置 Pyecharts
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK

# %%
data1 = pd.read_excel('超市.xlsx')
data1.head(1)
# Out:
#    行 ID            订单 ID       订单日期       发货日期 邮寄方式     客户 ID 客户名称  细分  城市  \
# 0     1  US-2018-1357144 2018-04-27 2018-04-29   二级  曾惠-14485   曾惠  公司  杭州
#
#   省/自治区  国家  地区            产品 ID    类别 子类别            产品名称      销售额  数量   折扣  \
# 0    浙江  中国  华东  办公用-用品-10002717  办公用品  用品  Fiskars 剪刀, 蓝色  129.696   2  0.4
#
#        利润
# 0 -60.704

# %% [markdown]
# ### 需求：分析一下各省的销售额分布情况

# %% [markdown]
# ###### 取数

# %%
data2 = data1.groupby('省/自治区')['销售额'].sum()
# 还是那理由
data2 = pd.DataFrame(data2)
data2.head(1)
# Out:
#               销售额
# 省/自治区
# 上海     582450.568

# %%
data2.head(1)
# Out:
#               销售额
# 省/自治区
# 上海     582450.568

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker

# 第一个值
x = data2.index.tolist()
# 第二个值
y = data2['销售额'].tolist()

c = (
    Geo()
    .add_schema(maptype="china")     # 👇 添加到这
    .add("geo", [list(z) for z in zip(x, y)])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-基本示例")
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="ec5ca5fabf1748989ff7a27c4ea4a922" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_ec5ca5fabf1748989ff7a27c4ea4a922 = echarts.init(
#                     document.getElementById('ec5ca5fabf1748989ff7a27c4ea4a922'), 'white', {renderer: 'canvas'});
#                 var option_ec5ca5fabf1748989ff7a27c4ea4a922 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         582450.568
#                     ]
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": [
#                         102.710002,
#                         25.045806,
#                         360925.768
#                     ]
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": [
#                         111.765617,
#                         40.817498,
#                         273453.012
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         409147.2
#                     ]
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": [
#                         125.32599,
#                         43.896536,
#                         640196.571
#                     ]
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": [
#                         104.075931,
#                         30.651651,
#                         400877.596
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         549906.63
#                     ]
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": [
#                         106.258754,
#                         38.471317,
#                         58121.0
#                     ]
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": [
#                         117.284922,
#                         31.861184,
#                         628965.19
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": [
#                         117.020359,
#                         36.66853,
#                         1586782.988
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": [
#                         112.562398,
#                         37.873531,
#                         423878.77
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         1452929.513
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": [
#                         108.327546,
#                         22.815478,
#                         377653.829
#                     ]
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": [
#                         87.627704,
#                         43.793026,
#                         70097.02
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         649967.22
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         237328.7
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": [
#                         114.468664,
#                         38.037057,
#                         790915.405
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": [
#                         113.753602,
#                         34.765515,
#                         853574.799
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         452108.244
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": [
#                         110.349228,
#                         20.017377,
#                         169256.843
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": [
#                         114.341861,
#                         30.546498,
#                         621960.332
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         723442.209
#                     ]
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": [
#                         103.826308,
#                         36.059421,
#                         179270.028
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": [
#                         119.295144,
#                         26.100779,
#                         546903.532
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": [
#                         91.117212,
#                         29.646922,
#                         10015.18
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": [
#                         106.70741,
#                         26.598194,
#                         108141.6
#                     ]
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": [
#                         123.42944,
#                         41.835441,
#                         862569.736
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         361761.93200000003
#                     ]

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker
from pyecharts.globals import ChartType

c = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "geo",
        [list(z) for z in zip(x, y)],
        type_=ChartType.HEATMAP,
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="Geo-HeatMap"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="645a26983f13484f9a7d3c556b450503" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_645a26983f13484f9a7d3c556b450503 = echarts.init(
#                     document.getElementById('645a26983f13484f9a7d3c556b450503'), 'white', {renderer: 'canvas'});
#                 var option_645a26983f13484f9a7d3c556b450503 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         582450.568
#                     ]
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": [
#                         102.710002,
#                         25.045806,
#                         360925.768
#                     ]
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": [
#                         111.765617,
#                         40.817498,
#                         273453.012
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         409147.2
#                     ]
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": [
#                         125.32599,
#                         43.896536,
#                         640196.571
#                     ]
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": [
#                         104.075931,
#                         30.651651,
#                         400877.596
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         549906.63
#                     ]
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": [
#                         106.258754,
#                         38.471317,
#                         58121.0
#                     ]
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": [
#                         117.284922,
#                         31.861184,
#                         628965.19
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": [
#                         117.020359,
#                         36.66853,
#                         1586782.988
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": [
#                         112.562398,
#                         37.873531,
#                         423878.77
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         1452929.513
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": [
#                         108.327546,
#                         22.815478,
#                         377653.829
#                     ]
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": [
#                         87.627704,
#                         43.793026,
#                         70097.02
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         649967.22
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         237328.7
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": [
#                         114.468664,
#                         38.037057,
#                         790915.405
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": [
#                         113.753602,
#                         34.765515,
#                         853574.799
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         452108.244
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": [
#                         110.349228,
#                         20.017377,
#                         169256.843
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": [
#                         114.341861,
#                         30.546498,
#                         621960.332
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         723442.209
#                     ]
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": [
#                         103.826308,
#                         36.059421,
#                         179270.028
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": [
#                         119.295144,
#                         26.100779,
#                         546903.532
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": [
#                         91.117212,
#                         29.646922,
#                         10015.18
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": [
#                         106.70741,
#                         26.598194,
#                         108141.6
#                     ]
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": [
#                         123.42944,
#                         41.835441,
#                         862569.736
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         361761.93200000003
#                     ]
#                 },
#                 {

# %% [markdown]
# #### 雷达图

# %% [markdown]
# #### 需求：查看一下各地区细分的销售额

# %%
data3 = data1.groupby(['地区','细分'])['销售额'].sum()
data3 = pd.DataFrame(data3).unstack()
data3
# Out:
#             销售额
# 细分           公司        小型企业          消费者
# 地区
# 东北   834842.827  522739.035  1323985.607
# 中南  1335665.324  743813.007  2057936.762
# 华东  1454715.808  942432.372  2287358.262
# 华北   804769.469  422100.987  1220430.561
# 西北   253458.184  103523.308   458058.104
# 西南   469341.684  156479.932   677302.892

# %%
# 取三个数据
data_1 = [data3['销售额']['公司'].tolist()]
data_2 = [data3['销售额']['小型企业'].tolist()]
data_3 = [data3['销售额']['消费者'].tolist()]
data_3
# Out:
# [[1323985.607, 2057936.762, 2287358.262, 1220430.561, 458058.104, 677302.892]]

# %%
import pyecharts.options as opts
from pyecharts.charts import Radar

"""
Gallery 使用 pyecharts 1.1.0
参考地址: https://echarts.apache.org/examples/editor.html?c=radar

目前无法实现的功能:

1、雷达图周围的图例的 textStyle 暂时无法设置背景颜色
"""
v1 = data_1
v2 = data_2
v3 = data_3

c = (
    Radar(init_opts=opts.InitOpts(bg_color="#CCCCCC"))
    .add_schema(
        schema=[
            opts.RadarIndicatorItem(name="东北", max_=2000000),
            opts.RadarIndicatorItem(name="中南", max_=2000000),
            opts.RadarIndicatorItem(name="华东", max_=2000000),
            opts.RadarIndicatorItem(name="华北", max_=2000000),
            opts.RadarIndicatorItem(name="西北", max_=2000000),
            opts.RadarIndicatorItem(name="西南", max_=2000000),
        ],
        splitarea_opt=opts.SplitAreaOpts(
            is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
        ),
        textstyle_opts=opts.TextStyleOpts(color="#fff"),
    )
    .add(
        series_name="预算分配（Allocated Budget）",
        data=v1,
        linestyle_opts=opts.LineStyleOpts(color="#CD0000"),
    )
    .add(
        series_name="实际开销（Actual Spending）",
        data=v2,
        linestyle_opts=opts.LineStyleOpts(color="#5CACEE"),
    )
    .add(
        series_name="分配（Allocated Budget）",
        data=v3,
        linestyle_opts=opts.LineStyleOpts(color="#CD0000"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="基础雷达图"), legend_opts=opts.LegendOpts()
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f2678822456a43c3b88334db093edaee" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f2678822456a43c3b88334db093edaee = echarts.init(
#                     document.getElementById('f2678822456a43c3b88334db093edaee'), 'white', {renderer: 'canvas'});
#                 var option_f2678822456a43c3b88334db093edaee = {
#     "backgroundColor": "#CCCCCC",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u9884\u7b97\u5206\u914d\uff08Allocated Budget\uff09",
#             "data": [
#                 [
#                     834842.827,
#                     1335665.324,
#                     1454715.808,
#                     804769.469,
#                     253458.184,
#                     469341.684
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#CD0000"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u5b9e\u9645\u5f00\u9500\uff08Actual Spending\uff09",
#             "data": [
#                 [
#                     522739.035,
#                     743813.007,
#                     942432.372,
#                     422100.987,
#                     103523.308,
#                     156479.932
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#5CACEE"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u5206\u914d\uff08Allocated Budget\uff09",
#             "data": [
#                 [
#                     1323985.607,
#                     2057936.762,
#                     2287358.262,
#                     1220430.561,
#                     458058.104,
#                     677302.892
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#CD0000"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9884\u7b97\u5206\u914d\uff08Allocated Budget\uff09",
#                 "\u5b9e\u9645\u5f00\u9500\uff08Actual Spending\uff09",
#                 "\u5206\u914d\uff08Allocated Budget\uff09"
#             ],
#             "selected": {
#                 "\u9884\u7b97\u5206\u914d\uff08Allocated Budget\uff09": true,
#                 "\u5b9e\u9645\u5f00\u9500\uff08Actual Spending\uff09": true,
#                 "\u5206\u914d\uff08Allocated Budget\uff09": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "radar": [
#         {
#             "indicator": [
#                 {
#                     "name": "\u4e1c\u5317",
#                     "max": 2000000
#                 },
#                 {
#                     "name": "\u4e2d\u5357",
#                     "max": 2000000
#                 },
#                 {
#                     "name": "\u534e\u4e1c",
#                     "max": 2000000
#                 },
#                 {
#                     "name": "\u534e\u5317",
#                     "max": 2000000
#                 },
#                 {
#                     "name": "\u897f\u5317",
#                     "max": 2000000
#                 },
#                 {
#                     "name": "\u897f\u5357",
#                     "max": 2000000
#                 }
#             ],
#             "startAngle": 90,
#             "name": {
#                 "textStyle": {
#                     "color": "#fff"
#                 }
#             },
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 1
#                 }
#             },
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u57fa\u7840\u96f7\u8fbe\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_f2678822456a43c3b88334db093edaee.setOption(option_f2678822456a43c3b88334db093edaee);
#         });
#     </script>

# %% [markdown]
# ### 漏斗图

# %% [markdown]
# #### 分析用户行为

# %%
data4 = pd.read_excel('./漏斗.xlsx')
data4
# Out:
#   用户主要行为     用户数
# 0    DAU  700000
# 1     登录  500000
# 2  加入购物车  300000
# 3   生成订单  210000
# 4     支付  150000
# 5   完成交易  140000

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel
from pyecharts.faker import Faker

# 取数
x = data4['用户主要行为']
y = data4['用户数']

lou = (
    Funnel()                       
    .add(
        "商品",              #  👇 放这
        [list(z) for z in zip(x,y)],
        # 👇 这个使 标签 放 内部
        label_opts = opts.LabelOpts(position = "inside")
    ) 
    .set_global_opts(title_opts=opts.TitleOpts(title="分析用户行为"))
)
lou.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="64e72be3e7014308b6e4e801eefbf2d9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_64e72be3e7014308b6e4e801eefbf2d9 = echarts.init(
#                     document.getElementById('64e72be3e7014308b6e4e801eefbf2d9'), 'white', {renderer: 'canvas'});
#                 var option_64e72be3e7014308b6e4e801eefbf2d9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "DAU",
#                     "value": 700000
#                 },
#                 {
#                     "name": "\u767b\u5f55",
#                     "value": 500000
#                 },
#                 {
#                     "name": "\u52a0\u5165\u8d2d\u7269\u8f66",
#                     "value": 300000
#                 },
#                 {
#                     "name": "\u751f\u6210\u8ba2\u5355",
#                     "value": 210000
#                 },
#                 {
#                     "name": "\u652f\u4ed8",
#                     "value": 150000
#                 },
#                 {
#                     "name": "\u5b8c\u6210\u4ea4\u6613",
#                     "value": 140000
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "DAU",
#                 "\u767b\u5f55",
#                 "\u5b8c\u6210\u4ea4\u6613",
#                 "\u751f\u6210\u8ba2\u5355",
#                 "\u52a0\u5165\u8d2d\u7269\u8f66",
#                 "\u652f\u4ed8"
#             ],
#             "selected": {
#                 "DAU": true,
#                 "\u767b\u5f55": true,
#                 "\u52a0\u5165\u8d2d\u7269\u8f66": true,
#                 "\u751f\u6210\u8ba2\u5355": true,
#                 "\u652f\u4ed8": true,
#                 "\u5b8c\u6210\u4ea4\u6613": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u5206\u6790\u7528\u6237\u884c\u4e3a",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_64e72be3e7014308b6e4e801eefbf2d9.setOption(option_64e72be3e7014308b6e4e801eefbf2d9);
#         });
#     </script>

# %% [markdown]
# #### 象形图

# %% [markdown]
# #### 需求：不同地区销售额对比

# %%
df1 = data1.groupby('地区')['销售额'].sum()
df1 = pd.DataFrame(df1)
df1
# Out:
#             销售额
# 地区
# 东北  2681567.469
# 中南  4137415.093
# 华东  4684506.442
# 华北  2447301.017
# 西北   815039.596
# 西南  1303124.508

# %%
# 取数
location = df1.index.to_list()
values =df1['销售额'].to_list()

# %%
from pyecharts import options as opts
from pyecharts.charts import PictorialBar
from pyecharts.globals import SymbolType

c = (
PictorialBar()  # 👇第一个参数
    .add_xaxis(location)
    .add_yaxis(
        "",
        # 👇 第二个参数
        values,
        label_opts=opts.LabelOpts(is_show=False),
        symbol_size=18,
        symbol_repeat="fixed",
        is_symbol_clip=True,
        symbol=SymbolType.ROUND_RECT
    )                     # 👆 这个是形状
    .reversal_axis()
    .set_global_opts(
        title_opts=opts.TitleOpts(title="各地区销售额分布"),
        xaxis_opts=opts.AxisOpts(is_show=False),
        yaxis_opts=opts.AxisOpts()
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="baab7fbdebdb45acabce7295a055197b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_baab7fbdebdb45acabce7295a055197b = echarts.init(
#                     document.getElementById('baab7fbdebdb45acabce7295a055197b'), 'white', {renderer: 'canvas'});
#                 var option_baab7fbdebdb45acabce7295a055197b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pictorialBar",
#             "symbol": "roundRect",
#             "symbolSize": 18,
#             "symbolRepeat": "fixed",
#             "symbolClip": true,
#             "data": [
#                 2681567.469,
#                 4137415.093,
#                 4684506.442,
#                 2447301.017,
#                 815039.596,
#                 1303124.508
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e1c\u5317",
#                 "\u4e2d\u5357",
#                 "\u534e\u4e1c",
#                 "\u534e\u5317",
#                 "\u897f\u5317",
#                 "\u897f\u5357"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u5404\u5730\u533a\u9500\u552e\u989d\u5206\u5e03",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_baab7fbdebdb45acabce7295a055197b.setOption(option_baab7fbdebdb45acabce7295a055197b);
#         });
#     </script>

# %% [markdown]
# #### 词云图

# %% [markdown]
# ##### 需求：分析热点省份

# %%
data1.columns
# Out:
# Index(['行 ID', '订单 ID', '订单日期', '发货日期', '邮寄方式', '客户 ID', '客户名称', '细分', '城市',
#        '省/自治区', '国家', '地区', '产品 ID', '类别', '子类别', '产品名称', '销售额', '数量', '折扣',
#        '利润'],
#       dtype='object')

# %%
data6 = data1.groupby('省/自治区')['销售额'].sum()
data6 = pd.DataFrame(data6)

# %%
# 取数
x_data = data6.index.tolist()
y_data = data6['销售额'].tolist()

# %%
# 给数整形
list_ = []
for i in range(len(x_data)):
    list_.append((x_data[i],y_data[i]))

# %%
import pyecharts.options as opts
from pyecharts.charts import WordCloud
from pyecharts.globals import ThemeType

ci = (
    WordCloud(init_opts=opts.InitOpts(theme = ThemeType.VINTAGE))                       # 👇 列表放这里
    .add(series_name="热点分析", data_pair=list_, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="热点分析", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
)
ci.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min', 'vintage':'https://assets.pyecharts.org/assets/v5/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="57269a8aa17c41a29e0b65f8a39daca1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud', 'vintage'], function(echarts) {
#                 var chart_57269a8aa17c41a29e0b65f8a39daca1 = echarts.init(
#                     document.getElementById('57269a8aa17c41a29e0b65f8a39daca1'), 'vintage', {renderer: 'canvas'});
#                 var option_57269a8aa17c41a29e0b65f8a39daca1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u70ed\u70b9\u5206\u6790",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 582450.568,
#                     "textStyle": {
#                         "color": "rgb(14,52,109)"
#                     }
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 360925.768,
#                     "textStyle": {
#                         "color": "rgb(51,154,78)"
#                     }
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 273453.012,
#                     "textStyle": {
#                         "color": "rgb(145,8,139)"
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 409147.2,
#                     "textStyle": {
#                         "color": "rgb(87,140,154)"
#                     }
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 640196.571,
#                     "textStyle": {
#                         "color": "rgb(72,145,18)"
#                     }
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 400877.596,
#                     "textStyle": {
#                         "color": "rgb(72,0,66)"
#                     }
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 549906.63,
#                     "textStyle": {
#                         "color": "rgb(78,53,127)"
#                     }
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 58121.0,
#                     "textStyle": {
#                         "color": "rgb(74,98,1)"
#                     }
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 628965.19,
#                     "textStyle": {
#                         "color": "rgb(23,84,104)"
#                     }
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 1586782.988,
#                     "textStyle": {
#                         "color": "rgb(60,90,148)"
#                     }
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 423878.77,
#                     "textStyle": {
#                         "color": "rgb(44,10,75)"
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1452929.513,
#                     "textStyle": {
#                         "color": "rgb(47,31,78)"
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 377653.829,
#                     "textStyle": {
#                         "color": "rgb(85,150,123)"
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 70097.02,
#                     "textStyle": {
#                         "color": "rgb(98,110,142)"
#                     }
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 649967.22,
#                     "textStyle": {
#                         "color": "rgb(68,140,1)"
#                     }
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 237328.7,
#                     "textStyle": {
#                         "color": "rgb(144,90,33)"
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 790915.405,
#                     "textStyle": {
#                         "color": "rgb(64,6,61)"
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 853574.799,
#                     "textStyle": {
#                         "color": "rgb(55,116,66)"
#                     }
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 452108.244,
#                     "textStyle": {
#                         "color": "rgb(95,55,52)"
#                     }
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 169256.843,
#                     "textStyle": {
#                         "color": "rgb(105,37,122)"
#                     }
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 621960.332,
#                     "textStyle": {
#                         "color": "rgb(149,49,139)"
#                     }
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 723442.209,
#                     "textStyle": {
#                         "color": "rgb(65,99,30)"
#                     }
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 179270.028,
#                     "textStyle": {
#                         "color": "rgb(152,37,139)"
#                     }
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 546903.532,
#                     "textStyle": {
#                         "color": "rgb(50,107,9)"
#                     }
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 10015.18,
#                     "textStyle": {
#                         "color": "rgb(4,54,156)"
#                     }
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 108141.6,
#                     "textStyle": {
#                         "color": "rgb(104,11,54)"
#                     }
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 862569.736,
#                     "textStyle": {
#                         "color": "rgb(135,150,112)"
#                     }
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 361761.93200000003,
#                     "textStyle": {
#                         "color": "rgb(158,48,97)"
#                     }
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 457688.168,
#                     "textStyle": {
#                         "colo

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Line, Grid

# 创建柱状图
bar = (
    Bar()
    .add_xaxis(["A", "B", "C", "D", "E"])
    .add_yaxis("Series A", [10, 20, 30, 40, 50])
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar Chart",pos_left="10%",pos_bottom="35%"),
        legend_opts=opts.LegendOpts(pos_left="15%"))
    )

# 创建折线图
line = (
    Line()
    .add_xaxis(["A", "B", "C", "D", "E"])
    .add_yaxis("Series B", [50, 40, 30, 20, 10])
    .set_global_opts(title_opts=opts.TitleOpts(title="Line Chart",pos_left="10%",pos_top="5%"),
                     legend_opts=opts.LegendOpts(pos_left="5%"))
)

# 创建 Grid 对象，并将柱状图和折线图添加到 Grid 对象中
grid = Grid(init_opts=opts.InitOpts(width="1000px", height="500px"))
grid.add(line, grid_opts=opts.GridOpts(pos_left="10%", pos_right="10%", pos_top="15%", height="40%"))
grid.add(bar, grid_opts=opts.GridOpts(pos_left="10%", pos_right="10%", pos_top="65%", height="25%"))

# 渲染图表
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bbfb5485a25e4e67a6a56093b4b659c2" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bbfb5485a25e4e67a6a56093b4b659c2 = echarts.init(
#                     document.getElementById('bbfb5485a25e4e67a6a56093b4b659c2'), 'white', {renderer: 'canvas'});
#                 var option_bbfb5485a25e4e67a6a56093b4b659c2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "Series B",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "A",
#                     50
#                 ],
#                 [
#                     "B",
#                     40
#                 ],
#                 [
#                     "C",
#                     30
#                 ],
#                 [
#                     "D",
#                     20
#                 ],
#                 [
#                     "E",
#                     10
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "bar",
#             "name": "Series A",
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "legendHoverLink": true,
#             "data": [
#                 10,
#                 20,
#                 30,
#                 40,
#                 50
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Series B"
#             ],
#             "selected": {
#                 "Series B": true
#             },
#             "show": true,
#             "left": "5%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         },
#         {
#             "data": [
#                 "Series A"
#             ],
#             "selected": {
#                 "Series A": true
#             },
#             "show": true,
#             "left": "15%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "A",
#                 "B",
#                 "C",
#                 "D",
#                 "E"
#             ]
#         },
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 1,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "A",
#                 "B",
#                 "C",
#                 "D",
#                 "E"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 1,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,

# %%
from pyecharts import options as opts
from pyecharts.charts import BMap
from pyecharts.faker import Faker

c = (
    BMap()
    .add_schema(baidu_ak="53oVIOgmSIejwV7EfphPgTynOZbIiVYu", center=[120.13066322374, 30.240018034923])
    .add(
        "bmap",
        [list(z) for z in zip(Faker.provinces, Faker.values())],
        label_opts=opts.LabelOpts(formatter="{b}"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="BMap-基本示例"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'bmap':'https://assets.pyecharts.org/assets/v5/bmap.min', 'baidu_map_api71':'https://api.map.baidu.com/api?v=2.0&ak=53oVIOgmSIejwV7EfphPgTynOZbIiVYu', 'baidu_map_api77':'https://api.map.baidu.com/getscript?v=2.0&ak=53oVIOgmSIejwV7EfphPgTynOZbIiVYu'
#         }
#     });
# </script>
#
#         <div id="c6fdeef6b5ed4cd59d58e72577df53a4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'bmap', 'baidu_map_api71', 'baidu_map_api77'], function(echarts) {
#                 var chart_c6fdeef6b5ed4cd59d58e72577df53a4 = echarts.init(
#                     document.getElementById('c6fdeef6b5ed4cd59d58e72577df53a4'), 'white', {renderer: 'canvas'});
#                 var option_c6fdeef6b5ed4cd59d58e72577df53a4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "bmap",
#             "coordinateSystem": "bmap",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c\u7701",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         79
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": [
#                         116.4,
#                         39.9,
#                         112
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": [
#                         121.47,
#                         31.23,
#                         33
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f\u7701",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         86
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         34
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f\u7701",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         131
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf\u7701",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         37
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "bmap"
#             ],
#             "selected": {
#                 "bmap": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "BMap-\u57fa\u672c\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "bmap": {
#         "center": [
#             120.13066322374,
#             30.240018034923
#         ],
#         "roam": true
#     }
# };
#                 chart_c6fdeef6b5ed4cd59d58e72577df53a4.setOption(option_c6fdeef6b5ed4cd59d58e72577df53a4);
#                     var bmap = chart_c6fdeef6b5ed4cd59d58e72577df53a4.getModel().getComponent('bmap').getBMap();
#                     bmap.addControl(new BMap.MapTypeControl());
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Boxplot

v1 = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880, 1000, 980],
    [960, 940, 960, 940, 880, 800, 850, 880, 900, 840, 830, 790],
]
v2 = [
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760, 910, 920],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850, 870, 870],
]
c = Boxplot()
c.add_xaxis(["expr1", "expr2"])
c.add_yaxis("A", c.prepare_data(v1))
c.add_yaxis("B", c.prepare_data(v2))
c.set_global_opts(title_opts=opts.TitleOpts(title="BoxPlot-基本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="de0296fc66504bd5a0635e3d993098b4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_de0296fc66504bd5a0635e3d993098b4 = echarts.init(
#                     document.getElementById('de0296fc66504bd5a0635e3d993098b4'), 'white', {renderer: 'canvas'});
#                 var option_de0296fc66504bd5a0635e3d993098b4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A",
#             "boxWidth": [
#                 7,
#                 50
#             ],
#             "selected_mode": false,
#             "data": [
#                 [
#                     740,
#                     857.5,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     790,
#                     832.5,
#                     880.0,
#                     940.0,
#                     960
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B",
#             "boxWidth": [
#                 7,
#                 50
#             ],
#             "selected_mode": false,
#             "data": [
#                 [
#                     740,
#                     760.0,
#                     805.0,
#                     872.5,
#                     920
#                 ],
#                 [
#                     760,
#                     795.0,
#                     815.0,
#                     865.0,
#                     890
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "expr1",
#                 "expr2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "BoxPlot-\u57fa\u672c\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_de0296fc66504bd5a0635e3d993098b4.setOption(option_de0296fc66504bd5a0635e3d993098b4);
#         });
#     </script>
